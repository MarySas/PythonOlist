# %%
### 1. Importing Visualization Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import scipy
from matplotlib.ticker import FormatStrFormatter

import os

# %%
matplotlib.__version__
# Out:
# '3.3.4'

# %%
#Import the database
path = r'C:\Users\Mary\Desktop\Data Analyst CF\Part 6'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_6_2.csv'), index_col=0)

# %%
pd.options.display.max_columns = None

# %%
pd.options.display.max_rows = None

# %%
df.head(3)
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  a035b83b3628decee6e3823924e0c10f                 53.0
# 2  091107484dd7172f5dcfed173e4a960e                 50.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       287.0                 1.0             225.0
# 1                      2235.0                 3.0            1450.0
# 2                       260.0                 2.0             183.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               16.0               10.0              14.0
# 1               20.0               25.0              20.0
# 2               16.0                8.0              13.0
#
#                            order_id  order_item_id  \
# 0  e17e4f88e31525f7deef66779844ddce              1
# 1  b18cb761efbe70da4838435a349abd07              1
# 2  a7708ffa8966514c098d15e1abfa6417              1
#
# ...

# %%
# 2. Finding frequencies
#Photos
df['product_photos_qty'].value_counts(dropna = False).sort_index()
sns.distplot(df['product_photos_qty'], bins = 10)
# Out:
# C:\Users\Mary\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='product_photos_qty', ylabel='Density'>

# %%
#Product_name_lenght
df['product_name_lenght'].value_counts(dropna = False).sort_index()
sns.distplot(df['product_name_lenght'], bins = 5)
# Out:
# C:\Users\Mary\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='product_name_lenght', ylabel='Density'>

# %%
# product_description_lenght
df['product_description_lenght'].value_counts(dropna = False).sort_index()
sns.distplot(df['product_description_lenght'], bins = 5)
# Out:
# C:\Users\Mary\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='product_description_lenght', ylabel='Density'>

# %%
#product_weight_g
df['product_weight_g'].value_counts(dropna = False).sort_index()
sns.distplot(df['product_weight_g'], bins =30)
# Out:
# C:\Users\Mary\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='product_weight_g', ylabel='Density'>

# %%
#Seller_id
sns.histplot(df['seller_id'], bins = 30)
# Out:
# <AxesSubplot:xlabel='seller_id', ylabel='Count'>

# %%
# Best sellers
best_sellers = df['seller_id'].value_counts(dropna = False).reset_index().head(20)

# %%
best_sellers
# Out:
#                                index  seller_id
# 0   4a3ca9315b744ce9f8e9374361493884       2091
# 1   6560211a19b47992c3666cc44a7e94c0       2071
# 2   1f50f920176fa81dab994f9023523100       1998
# 3   cc419e0650a3c5ba77189a1882b7556a       1814
# 4   da8622b14eb17ae2831f4ac5b9dab84a       1648
# 5   955fee9216a65b617aa5c0531780ce60       1488
# 6   1025f0e2d44d7041d6cf58b6550e0bfa       1451
# 7   7c67e1448b00f6e969d365cea6b010ab       1442
# 8   7a67c85e85bb2ce8582c35f2203ad736       1215
# 9   ea8482cd71df3c1969d7b9473ff13abc       1213
# 10  3d871de0142ce09b7081e2b9d1733cb1       1175
# 11  4869f7a5dfa277a7dca6462dcf3b52b2       1169
# 12  8b321bb669392f5163d04c59e235e066       1010
# 13  cca3071e3e9bb7d12640c9fbe2301306        868
# 14  620c87c171fb2a6dd6e8bb4dec959fc6        797
# 15  a1043bafd471dff536d0c462352beb48        787
# 16  e9779976487b77c6d4ac45f75ec7afe9        748
# 17  f8db351d8c4c4c22c6835c19a46f01b0        743
# 18  d2374cbcbb3ca4ab1086534108cc3ab7        674
# ...

# %%
# Price
sns.histplot(df['price'], bins = 100)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
# Seller City
df['seller_city'].value_counts(dropna = False).reset_index().head(20)
# Out:
#                     index  seller_city
# 0               sao paulo        15203
# 1          rio de janeiro         7748
# 2          belo horizonte         3130
# 3               são paulo         2627
# 4                curitiba         1763
# 5                brasilia         1686
# 6                campinas         1674
# 7            porto alegre         1587
# 8                salvador         1417
# 9               guarulhos         1334
# 10  sao bernardo do campo          963
# 11                 osasco          859
# 12                 santos          816
# 13            santo andre          722
# 14              fortaleza          714
# 15                niteroi          706
# 16               sorocaba          703
# 17                 recife          667
# 18                goiania          637
# 19    sao jose dos campos          624

# %%
# I realise that the city são paulo and sao paulo are the same.

# %%
# Correcting cities. The first 250 best sellers were corrected. After that the amount of sales were less than 60 orders.

df['seller_city'] = df['seller_city'].replace('são paulo', 'sao paulo')
df['seller_city'] = df['seller_city'].replace('florianópolis', 'florianopolis')
df['seller_city'] = df['seller_city'].replace('niterói', 'niteroi')
df['seller_city'] = df['seller_city'].replace('brasília', 'brasilia')
df['seller_city'] = df['seller_city'].replace('são bernardo do campo', 'sao bernardo do campo')
df['seller_city'] = df['seller_city'].replace('são caetano do sul', 'sao caetano do sul')
df['seller_city'] = df['seller_city'].replace('santo andré', 'santo andre')
df['seller_city'] = df['seller_city'].replace('goiânia', 'goiania')
df['seller_city'] = df['seller_city'].replace('são jose dos campos', 'sao jose dos campos')
df['seller_city'] = df['seller_city'].replace('ribeirão preto', 'ribeirao preto')
df['seller_city'] = df['seller_city'].replace('jundiaí', 'jundiai')
df['seller_city'] = df['seller_city'].replace('belém', 'belem')
df['seller_city'] = df['seller_city'].replace('uberlândia', 'uberlandia')
df['seller_city'] = df['seller_city'].replace('são gonçalo', 'sao goncalo')
df['seller_city'] = df['seller_city'].replace('nova iguaçu', 'nova iguacu')
df['seller_city'] = df['seller_city'].replace('vitória', 'vitoria')
df['seller_city'] = df['seller_city'].replace('são josé do rio preto', 'sao jose do rio preto')
df['seller_city'] = df['seller_city'].replace('sao luís', 'sao luis')
df['seller_city'] = df['seller_city'].replace('carapicuíba', 'carapicuiba')
df['seller_city'] = df['seller_city'].replace('taboão da serra', 'taboao da serra')
df['seller_city'] = df['seller_city'].replace('taubaté', 'taubate')
df['seller_city'] = df['seller_city'].replace('são carlos', 'sao carlos')
df['seller_city'] = df['seller_city'].replace('mauá', 'maua')
df['seller_city'] = df['seller_city'].replace('maringá', 'maringa')
df['seller_city'] = df['seller_city'].replace('joão pessoa', 'joao pessoa')
df['seller_city'] = df['seller_city'].replace('maceió', 'maceio')
df['seller_city'] = df['seller_city'].replace('guarujá', 'guaruja')
df['seller_city'] = df['seller_city'].replace('macaé', 'macae')
df['seller_city'] = df['seller_city'].replace('petrópolis', 'petropolis')
df['seller_city'] = df['seller_city'].replace('sumaré', 'sumare')
df['seller_city'] = df['seller_city'].replace('jacareí', 'jacarei')
df['seller_city'] = df['seller_city'].replace('são josé', 'sao jose')
df['seller_city'] = df['seller_city'].replace('santana de parnaína', 'santana de parnaiba')
df['seller_city'] = df['seller_city'].replace('divinópolis', 'divinopolis')
df['seller_city'] = df['seller_city'].replace('são joão de meriti', 'sao joao de meriti')
df['seller_city'] = df['seller_city'].replace('poços de caldas', 'pocos de caldas')
df['seller_city'] = df['seller_city'].replace('bragança paulista', 'bragança paulista')
df['seller_city'] = df['seller_city'].replace('são josé dos pinhais', 'sao jose dos pinhais')
df['seller_city'] = df['seller_city'].replace('teresópolis', 'teresopolis')
df['seller_city'] = df['seller_city'].replace('jaboatão dos guararapes', 'jaboatao dos guararapes')
df['seller_city'] = df['seller_city'].replace('paulínia', 'paulinia')
df['seller_city'] = df['seller_city'].replace('aparecida de goiânia', 'aparecida de goiania')
df['seller_city'] = df['seller_city'].replace('anápolis', 'anapolis')
df['seller_city'] = df['seller_city'].replace('chapecó', 'chapeco')
df['seller_city'] = df['seller_city'].replace('ribeirão das neves', 'ribeirao das neves')
df['seller_city'] = df['seller_city'].replace('gravataí', 'gravatai')
df['seller_city'] = df['seller_city'].replace('são leopoldo', 'sao leopoldo')
df['seller_city'] = df['seller_city'].replace('vitória da conquista', 'vitoria da conquista')
df['seller_city'] = df['seller_city'].replace('balneário camburiú', 'balneario camburiu')
df['seller_city'] = df['seller_city'].replace('itanhaém', 'itanhaem')
df['seller_city'] = df['seller_city'].replace('hortolândia', 'hortolandia')
df['seller_city'] = df['seller_city'].replace('jaraguá do sul', 'jaragua do sul')
df['seller_city'] = df['seller_city'].replace('itajaí', 'itajai')
df['seller_city'] = df['seller_city'].replace('são joão da boa vista', 'sao joao da boa vista')
df['seller_city'] = df['seller_city'].replace('mairiporã', 'mairipora')
df['seller_city'] = df['seller_city'].replace('tupã', 'tupa')
df['seller_city'] = df['seller_city'].replace('são roque', 'sao roque')
df['seller_city'] = df['seller_city'].replace('ribeirão pires', 'ribeirão pires')
df['seller_city'] = df['seller_city'].replace('jaguariúna', 'jaguariuna')
df['seller_city'] = df['seller_city'].replace('criciúma', 'criciuma')
df['seller_city'] = df['seller_city'].replace('nilópolis', 'nilopolis')
df['seller_city'] = df['seller_city'].replace('embu-guaçu', 'embu-guacu')
df['seller_city'] = df['seller_city'].replace('foz do iguaçu', 'foz do iguacu')
df['seller_city'] = df['seller_city'].replace('petrópolis', 'petropolis')
df['seller_city'] = df['seller_city'].replace('são joão del rei', 'sao joao del rei')
df['seller_city'] = df['seller_city'].replace('rondonopólis', 'rondonopolis')
df['seller_city'] = df['seller_city'].replace('teófilo otoni', 'teofilo otoni')
df['seller_city'] = df['seller_city'].replace('paranaguá', 'paranagua')
df['seller_city'] = df['seller_city'].replace('mauá', 'maua')
df['seller_city'] = df['seller_city'].replace('itaúna', 'itauna')
df['seller_city'] = df['seller_city'].replace('sertãozinho', 'sertaozinho')
df['seller_city'] = df['seller_city'].replace('palhoça', 'palhoca')
df['seller_city'] = df['seller_city'].replace('tubarão', 'tubarao')

# %%
# Bar chart seller_city
best_cities = df['seller_city'].value_counts(dropna = False).reset_index().head(200)

# %%
best_cities
# Out:
#                        index  seller_city
# 0                  sao paulo        17830
# 1             rio de janeiro         7748
# 2             belo horizonte         3130
# 3                   brasilia         2110
# 4                   curitiba         1763
# 5                   campinas         1674
# 6               porto alegre         1587
# 7                   salvador         1417
# 8                  guarulhos         1334
# 9      sao bernardo do campo         1078
# 10                   niteroi         1022
# 11               santo andre          885
# 12                    osasco          859
# 13                    santos          816
# 14                   goiania          782
# 15                 fortaleza          714
# 16                  sorocaba          703
# 17                    recife          667
# 18             florianopolis          653
# 19                   jundiai          647
# 20       sao jose dos campos          624
# ...

# %%
sns.histplot(best_cities['seller_city'], bins = 10)
# Out:
# <AxesSubplot:xlabel='seller_city', ylabel='Count'>

# %%
# Seller State
df['seller_state'].value_counts(dropna = False).reset_index()
# Out:
#    index  seller_state
# 0     SP         47713
# 1     RJ         14511
# 2     MG         13176
# 3     RS          6291
# 4     PR          5765
# 5     SC          4134
# 6     BA          3823
# 7     GO          2292
# 8     ES          2253
# 9     DF          2208
# 10    PE          1791
# 11    CE          1466
# 12    PA          1055
# 13    MT          1054
# 14    MS           835
# 15    MA           803
# 16    PB           599
# 17    RN           550
# 18    PI           538
# 19    AL           437
# 20    SE           381
# 21    TO           327
# 22    RO           271
# 23    AM           167
# 24    AC            91
# 25    AP            82
# 26    RR            44

# %%
df['seller_state'].value_counts().sort_index().plot.bar()
plt.xlabel('States')
plt.ylabel('Nº of sales')
plt.title('Sales per State')
plt.xticks(color = 'black', rotation = 90, horizontalalignment = 'center')
plt.show()

# %%
# Customer City
df['customer_city'].value_counts(dropna = False).reset_index().head(40)
# Out:
#                     index  customer_city
# 0               sao paulo          23575
# 1                ibitinga           8071
# 2               são paulo           4768
# 3                curitiba           3049
# 4             santo andre           2692
# 5          belo horizonte           2516
# 6   sao jose do rio preto           2458
# 7          ribeirao preto           2441
# 8          rio de janeiro           2370
# 9                 maringa           2268
# 10              guarulhos           2026
# 11             piracicaba           2012
# 12        itaquaquecetuba           1728
# 13               campinas           1381
# 14                  salto           1357
# 15           praia grande           1336
# 16   campo limpo paulista           1224
# 17                guariba           1169
# 18  sao bernardo do campo           1008
# 19                jacarei            959
# 20                limeira            851
# 21           porto alegre            817
# ...

# %%
# Correcting the customers_city names
df['customer_city'] = df['customer_city'].replace('são paulo', 'sao paulo')
df['customer_city'] = df['customer_city'].replace('florianópolis', 'florianopolis')
df['customer_city'] = df['customer_city'].replace('niterói', 'niteroi')
df['customer_city'] = df['customer_city'].replace('brasília', 'brasilia')
df['customer_city'] = df['customer_city'].replace('são bernardo do campo', 'sao bernardo do campo')
df['customer_city'] = df['customer_city'].replace('são caetano do sul', 'sao caetano do sul')
df['customer_city'] = df['customer_city'].replace('santo andré', 'santo andre')
df['customer_city'] = df['customer_city'].replace('goiânia', 'goiania')
df['customer_city'] = df['customer_city'].replace('são jose dos campos', 'sao jose dos campos')
df['customer_city'] = df['customer_city'].replace('ribeirão preto', 'ribeirao preto')
df['customer_city'] = df['customer_city'].replace('jundiaí', 'jundiai')
df['customer_city'] = df['customer_city'].replace('belém', 'belem')
df['customer_city'] = df['customer_city'].replace('uberlândia', 'uberlandia')
df['customer_city'] = df['customer_city'].replace('são gonçalo', 'sao goncalo')
df['customer_city'] = df['customer_city'].replace('nova iguaçu', 'nova iguacu')
df['customer_city'] = df['customer_city'].replace('vitória', 'vitoria')
df['customer_city'] = df['customer_city'].replace('são josé do rio preto', 'sao jose do rio preto')
df['customer_city'] = df['customer_city'].replace('sao luís', 'sao luis')
df['customer_city'] = df['customer_city'].replace('carapicuíba', 'carapicuiba')
df['customer_city'] = df['customer_city'].replace('taboão da serra', 'taboao da serra')
df['customer_city'] = df['customer_city'].replace('taubaté', 'taubate')
df['customer_city'] = df['customer_city'].replace('são carlos', 'sao carlos')
df['customer_city'] = df['customer_city'].replace('mauá', 'maua')
df['customer_city'] = df['customer_city'].replace('maringá', 'maringa')
df['customer_city'] = df['customer_city'].replace('joão pessoa', 'joao pessoa')
df['customer_city'] = df['customer_city'].replace('maceió', 'maceio')
df['customer_city'] = df['customer_city'].replace('guarujá', 'guaruja')
df['customer_city'] = df['customer_city'].replace('macaé', 'macae')
df['customer_city'] = df['customer_city'].replace('petrópolis', 'petropolis')
df['customer_city'] = df['customer_city'].replace('sumaré', 'sumare')
df['customer_city'] = df['customer_city'].replace('jacareí', 'jacarei')
df['customer_city'] = df['customer_city'].replace('são josé', 'sao jose')
df['customer_city'] = df['customer_city'].replace('santana de parnaína', 'santana de parnaiba')
df['customer_city'] = df['customer_city'].replace('divinópolis', 'divinopolis')
df['customer_city'] = df['customer_city'].replace('são joão de meriti', 'sao joao de meriti')
df['customer_city'] = df['customer_city'].replace('poços de caldas', 'pocos de caldas')
df['customer_city'] = df['customer_city'].replace('bragança paulista', 'bragança paulista')
df['customer_city'] = df['customer_city'].replace('são josé dos pinhais', 'sao jose dos pinhais')
df['customer_city'] = df['customer_city'].replace('teresópolis', 'teresopolis')
df['customer_city'] = df['customer_city'].replace('jaboatão dos guararapes', 'jaboatao dos guararapes')
df['customer_city'] = df['customer_city'].replace('paulínia', 'paulinia')
df['customer_city'] = df['customer_city'].replace('aparecida de goiânia', 'aparecida de goiania')
df['customer_city'] = df['customer_city'].replace('anápolis', 'anapolis')
df['customer_city'] = df['customer_city'].replace('chapecó', 'chapeco')
df['customer_city'] = df['customer_city'].replace('ribeirão das neves', 'ribeirao das neves')
df['customer_city'] = df['customer_city'].replace('gravataí', 'gravatai')
df['customer_city'] = df['customer_city'].replace('são leopoldo', 'sao leopoldo')
df['customer_city'] = df['customer_city'].replace('vitória da conquista', 'vitoria da conquista')
df['customer_city'] = df['customer_city'].replace('balneário camburiú', 'balneario camburiu')
df['customer_city'] = df['customer_city'].replace('itanhaém', 'itanhaem')
df['customer_city'] = df['customer_city'].replace('hortolândia', 'hortolandia')
df['customer_city'] = df['customer_city'].replace('jaraguá do sul', 'jaragua do sul')
df['customer_city'] = df['customer_city'].replace('itajaí', 'itajai')
df['customer_city'] = df['customer_city'].replace('são joão da boa vista', 'sao joao da boa vista')
df['customer_city'] = df['customer_city'].replace('mairiporã', 'mairipora')
df['customer_city'] = df['customer_city'].replace('tupã', 'tupa')
df['customer_city'] = df['customer_city'].replace('são roque', 'sao roque')
df['customer_city'] = df['customer_city'].replace('ribeirão pires', 'ribeirão pires')
df['customer_city'] = df['customer_city'].replace('jaguariúna', 'jaguariuna')
df['customer_city'] = df['customer_city'].replace('criciúma', 'criciuma')
df['customer_city'] = df['customer_city'].replace('nilópolis', 'nilopolis')
df['customer_city'] = df['customer_city'].replace('embu-guaçu', 'embu-guacu')
df['customer_city'] = df['customer_city'].replace('foz do iguaçu', 'foz do iguacu')
df['customer_city'] = df['customer_city'].replace('petrópolis', 'petropolis')
df['customer_city'] = df['customer_city'].replace('são joão del rei', 'sao joao del rei')
df['customer_city'] = df['customer_city'].replace('rondonopólis', 'rondonopolis')
df['customer_city'] = df['customer_city'].replace('teófilo otoni', 'teofilo otoni')
df['customer_city'] = df['customer_city'].replace('paranaguá', 'paranagua')
df['customer_city'] = df['customer_city'].replace('mauá', 'maua')
df['customer_city'] = df['customer_city'].replace('itaúna', 'itauna')
df['customer_city'] = df['customer_city'].replace('sertãozinho', 'sertaozinho')
df['customer_city'] = df['customer_city'].replace('palhoça', 'palhoca')
df['customer_city'] = df['customer_city'].replace('tubarão', 'tubarao')

# %%
best_customer_cities = df['customer_city'].value_counts(dropna = False).reset_index().head(200)

# %%
best_customer_cities
# Out:
#                      index  customer_city
# 0                sao paulo          28343
# 1                 ibitinga           8071
# 2              santo andre           3068
# 3                 curitiba           3049
# 4    sao jose do rio preto           2742
# 5           belo horizonte           2516
# 6           ribeirao preto           2445
# 7           rio de janeiro           2370
# 8                  maringa           2286
# 9                guarulhos           2026
# 10              piracicaba           2012
# 11         itaquaquecetuba           1728
# 12                campinas           1381
# 13                   salto           1357
# 14            praia grande           1336
# 15    campo limpo paulista           1224
# 16                 guariba           1169
# 17   sao bernardo do campo           1161
# 18                 jacarei            959
# 19                 limeira            851
# 20                brasilia            847
# ...

# %%
sns.histplot(best_customer_cities['customer_city'], bins = 50)
# Out:
# <AxesSubplot:xlabel='customer_city', ylabel='Count'>

# %%
# Customer State
df['customer_state'].value_counts(dropna = False).reset_index()
# Out:
#    index  customer_state
# 0     SP           79744
# 1     MG            8876
# 2     PR            8859
# 3     RJ            4927
# 4     SC            4322
# 5     RS            2193
# 6     DF             878
# 7     BA             678
# 8     GO             525
# 9     PE             458
# 10    MA             398
# 11    ES             366
# 12    MT             146
# 13    CE              98
# 14    MS              58
# 15    RN              54
# 16    PB              39
# 17    RO              14
# 18    PI              11
# 19    SE              10
# 20    AM               3

# %%
df['customer_state'].value_counts().sort_index().plot.bar()
plt.xlabel('States')
plt.ylabel('Nº of sales')
plt.title('Orders per State')
plt.xticks(color = 'black', rotation = 90, horizontalalignment = 'center')
plt.show()

# %%
# Product_category_name
df['product_category_name'].value_counts(dropna = False).reset_index()
# Out:
#                                       index  product_category_name
# 0                            bed_bath_table                  11657
# 1                             health_beauty                   9721
# 2                            sports_leisure                   8717
# 3                           furniture_decor                   8534
# 4                     computers_accessories                   7901
# 5                                housewares                   7136
# 6                             watches_gifts                   6006
# 7                                 telephony                   4545
# 8                              garden_tools                   4440
# 9                                      auto                   4249
# 10                                     toys                   4127
# 11                               cool_stuff                   3841
# 12                                perfumery                   3481
# ...

# %%
df['product_category_name'].value_counts().plot.bar()
plt.xlabel('Categories')
plt.ylabel('Nº of orders')
plt.title('Orders per Category')
plt.xticks(color = 'black', rotation = 65, horizontalalignment = 'right')
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18, 5, forward=True)
fig.savefig('test2png.png', dpi=100)

plt.show()

# %%
# review_score
df['review_score'].value_counts(dropna = False).sort_index()
# Out:
# 1    12812
# 2     3827
# 3     9483
# 4    21709
# 5    64826
# Name: review_score, dtype: int64

# %%
sns.distplot(df['review_score'], bins = 10)
# Out:
# C:\Users\Mary\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='review_score', ylabel='Density'>

# %%
# review_category
df['review_category'].value_counts(dropna = False).sort_index()
# Out:
# Bad review       16639
# Good review      86535
# Medium review     9483
# Name: review_category, dtype: int64

# %%
df['review_category'].value_counts().plot.bar(color = ['green', 'brown', 'orange'])
plt.ylabel('Nº of orders')
plt.title('Orders per Reviews Category')
plt.xticks(color = 'black', rotation = 360, horizontalalignment = 'center')
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Good review'),
#   Text(1, 0, 'Bad review'),
#   Text(2, 0, 'Medium review')])

# %%
# save data
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_2.2.csv'))
